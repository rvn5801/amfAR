# %%
import openpyxl
wb = openpyxl.load_workbook('data/AIDSVu_State_NewDX_2023-20250726.xlsx')
ws = wb.active
for i, row in enumerate(ws.iter_rows(values_only=True)):
    print(row)
    if i > 4: break
# Out:
# ('2023 State New Diagnoses Data - AIDSVu', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, N
# ...

# %%
import pandas as pd

df = pd.read_excel('data/AIDSVu_State_NewDX_2023-20250726.xlsx')
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Columns: 413 entries, 2023 State New Diagnoses Data - AIDSVu to Unnamed: 412
# dtypes: object(413)
# memory usage: 177.6+ KB
# None

# %%
xls = pd.ExcelFile('data/AIDSVu_State_NewDX_2023-20250726.xlsx')

print('Sheets:', xls.sheet_names)
# Out:
# Sheets: ['Data', 'Data Methods']

# %%
import pandas as pd

file = 'data/AIDSVu_State_PrEP_2023_20250501.xlsx'
df = pd.read_excel(file)

print('----- COLUMN NAMES -----')
print(df.columns)

print('\n----- DATA TYPES -----')
print(df.dtypes)

print('\n----- FIRST 10 ROWS -----')
print(df.head(10))

print('\n----- DATA SHAPE -----')
print(df.shape)
# Out:
# ----- COLUMN NAMES -----
# Index(['2023 State PrEP Data - AIDSVu', 'Unnamed: 1', 'Unnamed: 2',
#        'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
#        'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28',
#        'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',
#        'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36',
#        'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39'],
#       dtype='object')
#
# ----- DATA TYPES -----
# 2023 State PrEP Data - AIDSVu    object
# Unnamed: 1                       object
# Unnamed: 2                       object
# Unnamed: 3                       object
# Unnamed: 4                       object
# ...

# %%
import pandas as pd

file = "data/AIDSVu_State_NewDX_2023-20250726.xlsx"

df = pd.read_excel(
    file,
    sheet_name="Data",   # read only the correct sheet
    skiprows=3           # skip the first 3 metadata rows
)

print(df.head(10))
print(df.columns)

print(df.info())
# Out:
#    Year  GEO ID State Abbreviation             State  \
# 0  2023       1                 AL           Alabama
# 1  2023       2                 AK            Alaska
# 2  2023       4                 AZ           Arizona
# 3  2023       5                 AR          Arkansas
# 4  2023       6                 CA        California
# 5  2023       8                 CO          Colorado
# 6  2023       9                 CT       Connecticut
# 7  2023      10                 DE          Delaware
# 8  2023      11                 DC  Washington, D.C.
# 9  2023      12                 FL           Florida
#
#    New Diagnoses\nState Rate New Diagnoses\nState Rate Stability  \
# 0                         17                                   Y
# 1                          5                                   Y
# 2                         15                                   Y
# 3                         12                                   Y
# ...
